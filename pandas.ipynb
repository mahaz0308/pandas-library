# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_html("https://www.w3schools.com/html/html_tables.asp")

# %%
df
# Out:
# [                        Company           Contact  Country
#  0           Alfreds Futterkiste      Maria Anders  Germany
#  1    Centro comercial Moctezuma   Francisco Chang   Mexico
#  2                  Ernst Handel     Roland Mendel  Austria
#  3                Island Trading     Helen Bennett       UK
#  4  Laughing Bacchus Winecellars   Yoshi Tannamuri   Canada
#  5  Magazzini Alimentari Riuniti  Giovanni Rovelli    Italy,
#            Tag                                        Description
#  0     <table>                                    Defines a table
#  1        <th>                   Defines a header cell in a table
#  2        <tr>                           Defines a row in a table
#  3        <td>                          Defines a cell in a table
#  4   <caption>                            Defines a table caption
#  5  <colgroup>  Specifies a group of one or more columns in a ...
#  6       <col>  Specifies column properties for each column wi...
# ...

# %%
df[1]
# Out:
#           Tag                                        Description
# 0     <table>                                    Defines a table
# 1        <th>                   Defines a header cell in a table
# 2        <tr>                           Defines a row in a table
# 3        <td>                          Defines a cell in a table
# 4   <caption>                            Defines a table caption
# 5  <colgroup>  Specifies a group of one or more columns in a ...
# 6       <col>  Specifies column properties for each column wi...
# 7     <thead>               Groups the header content in a table
# 8     <tbody>                 Groups the body content in a table
# 9     <tfoot>               Groups the footer content in a table

# %%
df[0]
# Out:
#                         Company           Contact  Country
# 0           Alfreds Futterkiste      Maria Anders  Germany
# 1    Centro comercial Moctezuma   Francisco Chang   Mexico
# 2                  Ernst Handel     Roland Mendel  Austria
# 3                Island Trading     Helen Bennett       UK
# 4  Laughing Bacchus Winecellars   Yoshi Tannamuri   Canada
# 5  Magazzini Alimentari Riuniti  Giovanni Rovelli    Italy

# %%
df=pd.read_html("https://www.w3schools.com/html/html_tables.asp")[0]
df
# Out:
#                         Company           Contact  Country
# 0           Alfreds Futterkiste      Maria Anders  Germany
# 1    Centro comercial Moctezuma   Francisco Chang   Mexico
# 2                  Ernst Handel     Roland Mendel  Austria
# 3                Island Trading     Helen Bennett       UK
# 4  Laughing Bacchus Winecellars   Yoshi Tannamuri   Canada
# 5  Magazzini Alimentari Riuniti  Giovanni Rovelli    Italy

# %%
df=pd.read_json("https://api.github.com/users/hadley/repos")

# %%
df.head(1)
# Out:
#                                          archive_url  archived  \
# 0  https://api.github.com/repos/hadley/15-state-o...     False
#
#                                        assignees_url  \
# 0  https://api.github.com/repos/hadley/15-state-o...
#
#                                            blobs_url  \
# 0  https://api.github.com/repos/hadley/15-state-o...
#
#                                         branches_url  \
# 0  https://api.github.com/repos/hadley/15-state-o...
#
#                                            clone_url  \
# 0  https://github.com/hadley/15-state-of-the-unio...
#
#                                    collaborators_url  \
# 0  https://api.github.com/repos/hadley/15-state-o...
#
#                                         comments_url  \
# 0  https://api.github.com/repos/hadley/15-state-o...
#
#                                          commits_url  \
# 0  https://api.github.com/repos/hadley/15-state-o...
#
# ...

# %%
df.to_csv("rrt.csv")

# %%
df["A"]=2

# %%
df.to_excel("./Desktop/abc.xlsx")

# %%
df=pd.read_csv("df.csv")

# %%
df.head()
# Out:
#      A    B    C    D
# 0  2.0  5.0  6.0  8.0
# 1  5.6  6.0  8.0  7.0
# 2  4.5  7.8  8.9  0.4
# 3  9.0  8.0  7.0  5.0

# %%
df=pd.read_csv("df.csv",encoding='cp1252')

# %%
df
# Out:
#      A    B    C    D
# 0  2.0  5.0  6.0  8.0
# 1  5.6  6.0  8.0  7.0
# 2  4.5  7.8  8.9  0.4
# 3  9.0  8.0  7.0  5.0

# %%
df=pd.read_csv("df.csv",encoding='cp1252',usecols=["C","D"])

# %%
df
# Out:
#      C    D
# 0  6.0  8.0
# 1  8.0  7.0
# 2  8.9  0.4
# 3  7.0  5.0

# %%
df=pd.read_csv("df.csv",usecols=["A","B","C","D"])

# %%
df
# Out:
#      A    B    C    D
# 0  2.0  5.0  6.0  8.0
# 1  5.6  6.0  8.0  7.0
# 2  4.5  7.8  8.9  0.4
# 3  9.0  8.0  7.0  5.0

# %%
obj=pd.Series([1,2,3,4])

# %%
obj
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
obj1=pd.Series([1,2,3,4,5],index=["A","B","C","D","E"])

# %%
obj1
# Out:
# A    1
# B    2
# C    3
# D    4
# E    5
# dtype: int64

# %%
obj1.index.name="CNIC"

# %%
obj1
# Out:
# CNIC
# A    1
# B    2
# C    3
# D    4
# E    5
# dtype: int64

# %%
obj2=pd.Series([6,7,8,9],index=["A","G","H","M"])
obj2.index.name="name"

# %%
obj2
# Out:
# name
# A    6
# G    7
# H    8
# M    9
# dtype: int64

# %%
print(obj1,obj2,sep="\n")
# Out:
# CNIC
# A    1
# B    2
# C    3
# D    4
# E    5
# dtype: int64
# name
# A    6
# G    7
# H    8
# M    9
# dtype: int64

# %%
obj1+obj2
# Out:
# A    7.0
# B    NaN
# C    NaN
# D    NaN
# E    NaN
# G    NaN
# H    NaN
# M    NaN
# dtype: float64

# %%
##class 2

# %%
s1=pd.Series([1,2,3,4,5])

# %%
s2=pd.Series((6,7,8,9))

# %%
s2.index=["a","b","c","d"]

# %%
s2
# Out:
# a    6
# b    7
# c    8
# d    9
# dtype: int64

# %%
s2.index.name="id"

# %%
s2
# Out:
# id
# a    6
# b    7
# c    8
# d    9
# dtype: int64

# %%
d1={
    "A":1,
    "B":2,
    "C":3
    
}

# %%
s3=pd.Series(d1)

# %%
s3
# Out:
# A    1
# B    2
# C    3
# dtype: int64

# %%
data=[
    [1,"ALI","AI","1500"],
    [2,"MAHAZ","AS","1300"],
    [3,"AHMED","AI","4000"],
    [4,"SAAD","DS","4500"]
]

# %%
data
# Out:
# [[1, 'ALI', 'AI', '1500'],
#  [2, 'MAHAZ', 'AS', '1300'],
#  [3, 'AHMED', 'AI', '4000'],
#  [4, 'SAAD', 'DS', '4500']]

# %%
df1=pd.DataFrame(data)

# %%
df1
# Out:
#    0      1   2     3
# 0  1    ALI  AI  1500
# 1  2  MAHAZ  AS  1300
# 2  3  AHMED  AI  4000
# 3  4   SAAD  DS  4500

# %%
df1=pd.DataFrame(data,columns=["ID","NAME","COURSE","FEE"],index=range(5,9))

# %%
df1
# Out:
#    ID   NAME COURSE   FEE
# 5   1    ALI     AI  1500
# 6   2  MAHAZ     AS  1300
# 7   3  AHMED     AI  4000
# 8   4   SAAD     DS  4500

# %%
data=[(1,"mahaz","AI","5667"),
      (2,"ADNAN","AS","678"),
      (3,"GHAR","AI","5678")
    ]
df2=pd.DataFrame(data,columns=["ID","NAME","COURSE","FEE"],index=range(0,3))

# %%
df2
# Out:
#    ID   NAME COURSE   FEE
# 0   1  mahaz     AI  5667
# 1   2  ADNAN     AS   678
# 2   3   GHAR     AI  5678

# %%
d1 = {"ID": [1,2,3,4,5,6],
     "Name":['Ali',"Hamza","Junaid","Asif",'Ali',"Kashif"],
     'Course':['AIOT',"CNC","AI",'AIOT',"CNC","AI"],
     'Fee':[1000,1000,1200, 2000,1500,2000]}
d1
# Out:
# {'ID': [1, 2, 3, 4, 5, 6],
#  'Name': ['Ali', 'Hamza', 'Junaid', 'Asif', 'Ali', 'Kashif'],
#  'Course': ['AIOT', 'CNC', 'AI', 'AIOT', 'CNC', 'AI'],
#  'Fee': [1000, 1000, 1200, 2000, 1500, 2000]}

# %%
df3=pd.DataFrame(d1)

# %%
df3
# Out:
#    ID    Name Course   Fee
# 0   1     Ali   AIOT  1000
# 1   2   Hamza    CNC  1000
# 2   3  Junaid     AI  1200
# 3   4    Asif   AIOT  2000
# 4   5     Ali    CNC  1500
# 5   6  Kashif     AI  2000

# %%
df=pd.DataFrame(np.random.randint(1,100,size=(100,5)),columns=["A","B","C","D","E"])
df.head()
# Out:
#     A   B   C   D   E
# 0  90  90  46   4   3
# 1  32  14   2  46  75
# 2  87  17  81  95   8
# 3  73  64   1  51  14
# 4  14  27  14  64  58

# %%
df3
# Out:
#    ID    Name Course   Fee
# 0   1     Ali   AIOT  1000
# 1   2   Hamza    CNC  1000
# 2   3  Junaid     AI  1200
# 3   4    Asif   AIOT  2000
# 4   5     Ali    CNC  1500
# 5   6  Kashif     AI  2000

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 4 columns):
# ID        6 non-null int64
# Name      6 non-null object
# Course    6 non-null object
# Fee       6 non-null int64
# dtypes: int64(2), object(2)
# memory usage: 272.0+ bytes

# %%
df3.describe()
# Out:
#              ID          Fee
# count  6.000000     6.000000
# mean   3.500000  1450.000000
# std    1.870829   463.680925
# min    1.000000  1000.000000
# 25%    2.250000  1050.000000
# 50%    3.500000  1350.000000
# 75%    4.750000  1875.000000
# max    6.000000  2000.000000

# %%
df3.dtypes
# Out:
# ID         int64
# Name      object
# Course    object
# Fee        int64
# dtype: object

# %%
df3.count()
# Out:
# ID        6
# Name      6
# Course    6
# Fee       6
# dtype: int64

# %%
df3.isnull()
# Out:
#       ID   Name  Course    Fee
# 0  False  False   False  False
# 1  False  False   False  False
# 2  False  False   False  False
# 3  False  False   False  False
# 4  False  False   False  False
# 5  False  False   False  False

# %%
df3.isnull().sum()
# Out:
# ID        0
# Name      0
# Course    0
# Fee       0
# dtype: int64

# %%
df3.tail(2)
# Out:
#    ID    Name Course   Fee
# 4   5     Ali    CNC  1500
# 5   6  Kashif     AI  2000

# %%
df3
# Out:
#    ID    Name Course   Fee
# 0   1     Ali   AIOT  1000
# 1   2   Hamza    CNC  1000
# 2   3  Junaid     AI  1200
# 3   4    Asif   AIOT  2000
# 4   5     Ali    CNC  1500
# 5   6  Kashif     AI  2000

# %%
df3.sum(axis=0)[["ID","Fee"]]
# Out:
# ID       21
# Fee    8700
# dtype: object

# %%
df3.index
# Out:
# RangeIndex(start=0, stop=6, step=1)

# %%
df3.values
# Out:
# array([[1, 'Ali', 'AIOT', 1000],
#        [2, 'Hamza', 'CNC', 1000],
#        [3, 'Junaid', 'AI', 1200],
#        [4, 'Asif', 'AIOT', 2000],
#        [5, 'Ali', 'CNC', 1500],
#        [6, 'Kashif', 'AI', 2000]], dtype=object)

# %%
df3[df3.index<=2]
# Out:
#    ID    Name Course   Fee
# 0   1     Ali   AIOT  1000
# 1   2   Hamza    CNC  1000
# 2   3  Junaid     AI  1200

# %%
df3[df3.Fee>=1500]
# Out:
#    ID    Name Course   Fee
# 3   4    Asif   AIOT  2000
# 4   5     Ali    CNC  1500
# 5   6  Kashif     AI  2000

# %%
df3[df3.Fee<=1500]
# Out:
#    ID    Name Course   Fee
# 0   1     Ali   AIOT  1000
# 1   2   Hamza    CNC  1000
# 2   3  Junaid     AI  1200
# 4   5     Ali    CNC  1500

# %%
df3["Name"]
# Out:
# 0       Ali
# 1     Hamza
# 2    Junaid
# 3      Asif
# 4       Ali
# 5    Kashif
# Name: Name, dtype: object

# %%
df3.Fee
# Out:
# 0    1000
# 1    1000
# 2    1200
# 3    2000
# 4    1500
# 5    2000
# Name: Fee, dtype: int64

# %%
df3["Update Fee"]=0

# %%
df3
# Out:
#    ID    Name Course   Fee  Update Fee
# 0   1     Ali   AIOT  1000           0
# 1   2   Hamza    CNC  1000           0
# 2   3  Junaid     AI  1200           0
# 3   4    Asif   AIOT  2000           0
# 4   5     Ali    CNC  1500           0
# 5   6  Kashif     AI  2000           0

# %%
df3.Timing = 700

# %%
d1={
    "AIOT":2,
    "AI":2,
    "CNC":1
}

# %%
df3
# Out:
#    ID    Name Course   Fee  Update Fee
# 0   1     Ali   AIOT  1000           0
# 1   2   Hamza    CNC  1000           0
# 2   3  Junaid     AI  1200           0
# 3   4    Asif   AIOT  2000           0
# 4   5     Ali    CNC  1500           0
# 5   6  Kashif     AI  2000           0

# %%
df3["Update Course"]=df3.Course.value_counts()

# %%
df3
# Out:
#    ID    Name Course   Fee  Update Fee  Update Course
# 0   1     Ali   AIOT  1000           0            NaN
# 1   2   Hamza    CNC  1000           0            NaN
# 2   3  Junaid     AI  1200           0            NaN
# 3   4    Asif   AIOT  2000           0            NaN
# 4   5     Ali    CNC  1500           0            NaN
# 5   6  Kashif     AI  2000           0            NaN

# %%
df3.Course.unique()
# Out:
# array(['AIOT', 'CNC', 'AI'], dtype=object)

# %%
df3.Course.value_counts()
# Out:
# CNC     2
# AI      2
# AIOT    2
# Name: Course, dtype: int64

# %%
def f1(x):
    if x=="AIOT":
        return 10000
    elif x=="CNC":
        return 15000
    elif x=="AI":
        return 20000
    else:
        return 0

# %%
df3.Course.apply(f1)
# Out:
# 0    10000
# 1    15000
# 2    20000
# 3    10000
# 4    15000
# 5    20000
# Name: Course, dtype: int64

# %%
df3["Update fee"]=df3.Course.apply(f1)

# %%
df3
# Out:
#    ID    Name Course   Fee  Update Fee  Update Course  Update fee
# 0   1     Ali   AIOT  1000           0            NaN       10000
# 1   2   Hamza    CNC  1000           0            NaN       15000
# 2   3  Junaid     AI  1200           0            NaN       20000
# 3   4    Asif   AIOT  2000           0            NaN       10000
# 4   5     Ali    CNC  1500           0            NaN       15000
# 5   6  Kashif     AI  2000           0            NaN       20000

# %%
df3.drop("Update fee",axis=1)
# Out:
#    ID    Name Course   Fee  Update Fee  Update Course
# 0   1     Ali   AIOT  1000           0            NaN
# 1   2   Hamza    CNC  1000           0            NaN
# 2   3  Junaid     AI  1200           0            NaN
# 3   4    Asif   AIOT  2000           0            NaN
# 4   5     Ali    CNC  1500           0            NaN
# 5   6  Kashif     AI  2000           0            NaN

# %%
df3=df3.drop("Update Course",axis=1)

# %%
df3
# Out:
#    ID    Name Course   Fee  Update Fee  Update fee
# 0   1     Ali   AIOT  1000           0       10000
# 1   2   Hamza    CNC  1000           0       15000
# 2   3  Junaid     AI  1200           0       20000
# 3   4    Asif   AIOT  2000           0       10000
# 4   5     Ali    CNC  1500           0       15000
# 5   6  Kashif     AI  2000           0       20000

# %%
df3=df3.drop("Update Fee",axis=1)

# %%
df3
# Out:
#    ID    Name Course   Fee  Update fee
# 0   1     Ali   AIOT  1000       10000
# 1   2   Hamza    CNC  1000       15000
# 2   3  Junaid     AI  1200       20000
# 3   4    Asif   AIOT  2000       10000
# 4   5     Ali    CNC  1500       15000
# 5   6  Kashif     AI  2000       20000

# %%
df3.Course.value_counts()
# Out:
# CNC     2
# AI      2
# AIOT    2
# Name: Course, dtype: int64

# %%
d1={
    "AIOT":2,
    "CNC":2,
    "AI":2
}

# %%
df3["Update Couse"]=df3.Course.map(d1)

# %%
df3
# Out:
#    ID    Name Course   Fee  Update fee  Update Couse
# 0   1     Ali   AIOT  1000       10000             2
# 1   2   Hamza    CNC  1000       15000             2
# 2   3  Junaid     AI  1200       20000             2
# 3   4    Asif   AIOT  2000       10000             2
# 4   5     Ali    CNC  1500       15000             2
# 5   6  Kashif     AI  2000       20000             2

# %%
df4=pd.DataFrame(np.random.randint(1,100, size=(6,5)),columns=["A","B","C","D","E"])

# %%
df4
# Out:
#     A   B   C   D   E
# 0  30  42  55  29  84
# 1   2  78  84  11  71
# 2  15  55  63  34  42
# 3  60  26  75  19  27
# 4  36  91  31  98  65
# 5  19  83  46  32   1

# %%
df=pd.concat([df3,df4],axis=1)

# %%
df
# Out:
#    ID    Name Course   Fee  Update fee  Update Couse   A   B   C   D   E
# 0   1     Ali   AIOT  1000       10000             2  30  42  55  29  84
# 1   2   Hamza    CNC  1000       15000             2   2  78  84  11  71
# 2   3  Junaid     AI  1200       20000             2  15  55  63  34  42
# 3   4    Asif   AIOT  2000       10000             2  60  26  75  19  27
# 4   5     Ali    CNC  1500       15000             2  36  91  31  98  65
# 5   6  Kashif     AI  2000       20000             2  19  83  46  32   1

# %%
def grade(x):
    if x>=90:
        return "A"
    elif x>=80:
        return "B"
    elif x>=70:
        return "C"
    elif x>=60:
        return "D"
    elif x>=50:
        return "E"
    else:
        return "FAIL"

# %%
df["Total"]=df.A+df.B+df.C+df.D+df.E
df["Percentage"]=df.Total/500*100
df["Grade"]=df.Percentage.apply(grade)

# %%
df
# Out:
#    ID    Name Course   Fee  Update fee  Update Couse   A   B   C   D   E  \
# 0   1     Ali   AIOT  1000       10000             2  30  42  55  29  84
# 1   2   Hamza    CNC  1000       15000             2   2  78  84  11  71
# 2   3  Junaid     AI  1200       20000             2  15  55  63  34  42
# 3   4    Asif   AIOT  2000       10000             2  60  26  75  19  27
# 4   5     Ali    CNC  1500       15000             2  36  91  31  98  65
# 5   6  Kashif     AI  2000       20000             2  19  83  46  32   1
#
#    Total  Percentage Grade
# 0    240        48.0  FAIL
# 1    246        49.2  FAIL
# 2    209        41.8  FAIL
# 3    207        41.4  FAIL
# 4    321        64.2     D
# 5    181        36.2  FAIL

# %%
df[["Course","A","B","C","D","E"]]
# Out:
#   Course   A   B   C   D   E
# 0   AIOT  30  42  55  29  84
# 1    CNC   2  78  84  11  71
# 2     AI  15  55  63  34  42
# 3   AIOT  60  26  75  19  27
# 4    CNC  36  91  31  98  65
# 5     AI  19  83  46  32   1

# %%
df.sort_index(ascending=False,axis=0)
# Out:
#    ID    Name Course   Fee  Update fee  Update Couse   A   B   C   D   E  \
# 5   6  Kashif     AI  2000       20000             2  19  83  46  32   1
# 4   5     Ali    CNC  1500       15000             2  36  91  31  98  65
# 3   4    Asif   AIOT  2000       10000             2  60  26  75  19  27
# 2   3  Junaid     AI  1200       20000             2  15  55  63  34  42
# 1   2   Hamza    CNC  1000       15000             2   2  78  84  11  71
# 0   1     Ali   AIOT  1000       10000             2  30  42  55  29  84
#
#    Total  Percentage Grade
# 5    181        36.2  FAIL
# 4    321        64.2     D
# 3    207        41.4  FAIL
# 2    209        41.8  FAIL
# 1    246        49.2  FAIL
# 0    240        48.0  FAIL

# %%
df.sort_values("Percentage",ascending=False,axis=0)
# Out:
#    ID    Name Course   Fee  Update fee  Update Couse   A   B   C   D   E  \
# 4   5     Ali    CNC  1500       15000             2  36  91  31  98  65
# 1   2   Hamza    CNC  1000       15000             2   2  78  84  11  71
# 0   1     Ali   AIOT  1000       10000             2  30  42  55  29  84
# 2   3  Junaid     AI  1200       20000             2  15  55  63  34  42
# 3   4    Asif   AIOT  2000       10000             2  60  26  75  19  27
# 5   6  Kashif     AI  2000       20000             2  19  83  46  32   1
#
#    Total  Percentage Grade
# 4    321        64.2     D
# 1    246        49.2  FAIL
# 0    240        48.0  FAIL
# 2    209        41.8  FAIL
# 3    207        41.4  FAIL
# 5    181        36.2  FAIL

# %%
df.sort_values(by=["Course","Percentage"],ascending=[True,False],axis=0)
# Out:
#    ID    Name Course   Fee  Update fee  Update Couse   A   B   C   D   E  \
# 2   3  Junaid     AI  1200       20000             2  15  55  63  34  42
# 5   6  Kashif     AI  2000       20000             2  19  83  46  32   1
# 0   1     Ali   AIOT  1000       10000             2  30  42  55  29  84
# 3   4    Asif   AIOT  2000       10000             2  60  26  75  19  27
# 4   5     Ali    CNC  1500       15000             2  36  91  31  98  65
# 1   2   Hamza    CNC  1000       15000             2   2  78  84  11  71
#
#    Total  Percentage Grade
# 2    209        41.8  FAIL
# 5    181        36.2  FAIL
# 0    240        48.0  FAIL
# 3    207        41.4  FAIL
# 4    321        64.2     D
# 1    246        49.2  FAIL

# %%
df1=pd.DataFrame({"CNIC":np.random.randint(1,20, size=20),
                 "Acount No":np.random.randint(1,5, size=20)})
df1
# Out:
#     CNIC  Acount No
# 0     18          4
# 1     18          2
# 2     18          3
# 3     11          2
# 4      4          3
# 5     19          3
# 6      6          1
# 7     16          1
# 8      6          3
# 9     16          4
# 10     4          4
# 11    11          2
# 12     6          1
# 13     6          2
# 14    17          4
# 15    18          1
# 16     5          2
# 17    19          1
# 18     9          3
# 19    14          3

# %%
df2=pd.DataFrame({"CNIC":np.random.randint(1,20, size=20),
                 "Acount No":np.random.randint(2001,3000, size=20),
                  "DOB":pd.date_range( '1990-01-01', periods=20,freq="Y"),
                  "Mobile no":np.random.randint(1,5, size=20),
                  "CustomerName":[chr(x) for x in np.random.randint(65,91,size=20)],
                  "Gender":np.random.choice(["M","N"], size=(20))})

# %%
df2
# Out:
#     CNIC  Acount No        DOB  Mobile no CustomerName Gender
# 0      2       2156 1990-12-31          4            R      N
# 1      8       2560 1991-12-31          1            Z      M
# 2     18       2728 1992-12-31          3            B      M
# 3     11       2156 1993-12-31          3            H      M
# 4      2       2767 1994-12-31          1            T      N
# 5     12       2282 1995-12-31          2            J      N
# 6      1       2869 1996-12-31          1            W      N
# 7     12       2009 1997-12-31          2            N      M
# 8      8       2231 1998-12-31          3            I      M
# 9      8       2593 1999-12-31          2            C      M
# 10    12       2266 2000-12-31          1            Z      M
# 11    15       2172 2001-12-31          2            F      M
# 12    12       2548 2002-12-31          2            L      M
# 13     5       2212 2003-12-31          2            F      M
# ...

# %%
a=df1.merge(df2, on="CNIC", how="inner")

# %%
a
# Out:
#    CNIC  Acount No_x  Acount No_y        DOB  Mobile no CustomerName Gender
# 0    18            4         2728 1992-12-31          3            B      M
# 1    18            2         2728 1992-12-31          3            B      M
# 2    18            3         2728 1992-12-31          3            B      M
# 3    18            1         2728 1992-12-31          3            B      M
# 4    11            2         2156 1993-12-31          3            H      M
# 5    11            2         2156 1993-12-31          3            H      M
# 6     4            3         2318 2009-12-31          1            B      M
# 7     4            4         2318 2009-12-31          1            B      M
# 8     5            2         2212 2003-12-31          2            F      M
# 9     9            3         2900 2004-12-31          2            R      N

# %%
a=df1.merge(df2, on=["CNIC","Acount No"], how="inner")

# %%
a
# Out:
# Empty DataFrame
# Columns: [CNIC, Acount No, DOB, Mobile no, CustomerName, Gender]
# Index: []

# %%
a
# Out:
# Empty DataFrame
# Columns: [CNIC, Acount No, DOB, Mobile no, CustomerName, Gender]
# Index: []

# %%
df1.columns=["Customer CNIC","Customer Acount No"]

# %%
df1
# Out:
#     Customer CNIC  Customer Acount No
# 0              18                   4
# 1              18                   2
# 2              18                   3
# 3              11                   2
# 4               4                   3
# 5              19                   3
# 6               6                   1
# 7              16                   1
# 8               6                   3
# 9              16                   4
# 10              4                   4
# 11             11                   2
# 12              6                   1
# 13              6                   2
# 14             17                   4
# 15             18                   1
# 16              5                   2
# 17             19                   1
# 18              9                   3
# 19             14                   3

# %%
a=df1.merge(df2,left_on="Customer CNIC",right_on="CNIC")

# %%
df2
# Out:
#     CNIC  Acount No        DOB  Mobile no CustomerName Gender
# 0      2       2156 1990-12-31          4            R      N
# 1      8       2560 1991-12-31          1            Z      M
# 2     18       2728 1992-12-31          3            B      M
# 3     11       2156 1993-12-31          3            H      M
# 4      2       2767 1994-12-31          1            T      N
# 5     12       2282 1995-12-31          2            J      N
# 6      1       2869 1996-12-31          1            W      N
# 7     12       2009 1997-12-31          2            N      M
# 8      8       2231 1998-12-31          3            I      M
# 9      8       2593 1999-12-31          2            C      M
# 10    12       2266 2000-12-31          1            Z      M
# 11    15       2172 2001-12-31          2            F      M
# 12    12       2548 2002-12-31          2            L      M
# 13     5       2212 2003-12-31          2            F      M
# ...

# %%
a
# Out:
#    Customer CNIC  Customer Acount No  CNIC  Acount No        DOB  Mobile no  \
# 0             18                   4    18       2728 1992-12-31          3
# 1             18                   2    18       2728 1992-12-31          3
# 2             18                   3    18       2728 1992-12-31          3
# 3             18                   1    18       2728 1992-12-31          3
# 4             11                   2    11       2156 1993-12-31          3
# 5             11                   2    11       2156 1993-12-31          3
# 6              4                   3     4       2318 2009-12-31          1
# 7              4                   4     4       2318 2009-12-31          1
# 8              5                   2     5       2212 2003-12-31          2
# 9              9                   3     9       2900 2004-12-31          2
#
#   CustomerName Gender
# 0            B      M
# 1            B      M
# 2            B      M
# 3            B      M
# ...

# %%
a=df1.merge(df2,left_on=["Customer CNIC","Customer Acount No"],right_on=["CNIC","Acount No"])

# %%
a
# Out:
# Empty DataFrame
# Columns: [Customer CNIC, Customer Acount No, CNIC, Acount No, DOB, Mobile no, CustomerName, Gender]
# Index: []

# %%
df1
# Out:
#     Customer CNIC  Customer Acount No
# 0              18                   4
# 1              18                   2
# 2              18                   3
# 3              11                   2
# 4               4                   3
# 5              19                   3
# 6               6                   1
# 7              16                   1
# 8               6                   3
# 9              16                   4
# 10              4                   4
# 11             11                   2
# 12              6                   1
# 13              6                   2
# 14             17                   4
# 15             18                   1
# 16              5                   2
# 17             19                   1
# 18              9                   3
# 19             14                   3

# %%
df2
# Out:
#     CNIC  Acount No        DOB  Mobile no CustomerName Gender
# 0      2       2156 1990-12-31          4            R      N
# 1      8       2560 1991-12-31          1            Z      M
# 2     18       2728 1992-12-31          3            B      M
# 3     11       2156 1993-12-31          3            H      M
# 4      2       2767 1994-12-31          1            T      N
# 5     12       2282 1995-12-31          2            J      N
# 6      1       2869 1996-12-31          1            W      N
# 7     12       2009 1997-12-31          2            N      M
# 8      8       2231 1998-12-31          3            I      M
# 9      8       2593 1999-12-31          2            C      M
# 10    12       2266 2000-12-31          1            Z      M
# 11    15       2172 2001-12-31          2            F      M
# 12    12       2548 2002-12-31          2            L      M
# 13     5       2212 2003-12-31          2            F      M
# ...

# %%
df1.merge(df2,left_on="Customer CNIC",right_on="CNIC")
# Out:
#    Customer CNIC  Customer Acount No  CNIC  Acount No        DOB  Mobile no  \
# 0             18                   4    18       2728 1992-12-31          3
# 1             18                   2    18       2728 1992-12-31          3
# 2             18                   3    18       2728 1992-12-31          3
# 3             18                   1    18       2728 1992-12-31          3
# 4             11                   2    11       2156 1993-12-31          3
# 5             11                   2    11       2156 1993-12-31          3
# 6              4                   3     4       2318 2009-12-31          1
# 7              4                   4     4       2318 2009-12-31          1
# 8              5                   2     5       2212 2003-12-31          2
# 9              9                   3     9       2900 2004-12-31          2
#
#   CustomerName Gender
# 0            B      M
# 1            B      M
# 2            B      M
# 3            B      M
# ...

# %%
df1.merge(df2,left_on="Customer CNIC",right_on="Acount No")
# Out:
# Empty DataFrame
# Columns: [Customer CNIC, Customer Acount No, CNIC, Acount No, DOB, Mobile no, CustomerName, Gender]
# Index: []

# %%
df1.merge(df2,left_on="Customer CNIC",right_on="Acount No",how="left")
# Out:
#     Customer CNIC  Customer Acount No  CNIC  Acount No DOB  Mobile no  \
# 0              18                   4   NaN        NaN NaT        NaN
# 1              18                   2   NaN        NaN NaT        NaN
# 2              18                   3   NaN        NaN NaT        NaN
# 3              11                   2   NaN        NaN NaT        NaN
# 4               4                   3   NaN        NaN NaT        NaN
# 5              19                   3   NaN        NaN NaT        NaN
# 6               6                   1   NaN        NaN NaT        NaN
# 7              16                   1   NaN        NaN NaT        NaN
# 8               6                   3   NaN        NaN NaT        NaN
# 9              16                   4   NaN        NaN NaT        NaN
# 10              4                   4   NaN        NaN NaT        NaN
# 11             11                   2   NaN        NaN NaT        NaN
# ...

# %%
df1
# Out:
#     Customer CNIC  Customer Acount No
# 0              18                   4
# 1              18                   2
# 2              18                   3
# 3              11                   2
# 4               4                   3
# 5              19                   3
# 6               6                   1
# 7              16                   1
# 8               6                   3
# 9              16                   4
# 10              4                   4
# 11             11                   2
# 12              6                   1
# 13              6                   2
# 14             17                   4
# 15             18                   1
# 16              5                   2
# 17             19                   1
# 18              9                   3
# 19             14                   3

# %%
df2
# Out:
#     CNIC  Acount No        DOB  Mobile no CustomerName Gender
# 0      2       2156 1990-12-31          4            R      N
# 1      8       2560 1991-12-31          1            Z      M
# 2     18       2728 1992-12-31          3            B      M
# 3     11       2156 1993-12-31          3            H      M
# 4      2       2767 1994-12-31          1            T      N
# 5     12       2282 1995-12-31          2            J      N
# 6      1       2869 1996-12-31          1            W      N
# 7     12       2009 1997-12-31          2            N      M
# 8      8       2231 1998-12-31          3            I      M
# 9      8       2593 1999-12-31          2            C      M
# 10    12       2266 2000-12-31          1            Z      M
# 11    15       2172 2001-12-31          2            F      M
# 12    12       2548 2002-12-31          2            L      M
# 13     5       2212 2003-12-31          2            F      M
# ...

# %%
c=df2.groupby("CustomerName")["CNIC"].agg("count")

# %%
c
# Out:
# CustomerName
# B    2
# C    1
# F    2
# H    1
# I    2
# J    1
# L    1
# N    1
# P    1
# R    2
# T    2
# W    1
# X    1
# Z    2
# Name: CNIC, dtype: int64

# %%
c
# Out:
# CustomerName
# B    2
# C    1
# F    2
# H    1
# I    2
# J    1
# L    1
# N    1
# P    1
# R    2
# T    2
# W    1
# X    1
# Z    2
# Name: CNIC, dtype: int64

# %%
c=df2.groupby(["Gender","CNIC"])["Acount No"].agg(["count","sum","min","max"])

# %%
c
# Out:
#              count   sum   min   max
# Gender CNIC
# M      4         1  2318  2318  2318
#        5         1  2212  2212  2212
#        8         3  7384  2231  2593
#        10        1  2962  2962  2962
#        11        1  2156  2156  2156
#        12        3  6823  2009  2548
#        15        1  2172  2172  2172
#        18        1  2728  2728  2728
# N      1         3  7196  2049  2869
#        2         2  4923  2156  2767
#        7         1  2674  2674  2674
#        9         1  2900  2900  2900
#        12        1  2282  2282  2282

# %% [markdown]
# # dandling missing values

# %%
string_data=pd.Series(["mahaz","adeel","ahmed",np.nan,"saad","mujfid"])

# %%
string_data
# Out:
# 0     mahaz
# 1     adeel
# 2     ahmed
# 3       NaN
# 4      saad
# 5    mujfid
# dtype: object

# %%
string_data.isnull()
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# 5    False
# dtype: bool

# %%
string_data.isna()
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# 5    False
# dtype: bool

# %%
string_data.notnull()
# Out:
# 0     True
# 1     True
# 2     True
# 3    False
# 4     True
# 5     True
# dtype: bool

# %%
string_data[string_data.isnull()]
# Out:
# 3    NaN
# dtype: object

# %%
string_data[0]=None

# %%
string_data
# Out:
# 0      None
# 1     adeel
# 2     ahmed
# 3       NaN
# 4      saad
# 5    mujfid
# dtype: object

# %%
string_data.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# dtype: bool

# %%
string_data.dropna()
# Out:
# 1     adeel
# 2     ahmed
# 4      saad
# 5    mujfid
# dtype: object

# %%
from numpy import nan as NA
data=pd.DataFrame([[1.,4.5,8],[1.,NA,NA],[NA,NA,NA],[NA,6.5,8]])

# %%
data
# Out:
#      0    1    2
# 0  1.0  4.5  8.0
# 1  1.0  NaN  NaN
# 2  NaN  NaN  NaN
# 3  NaN  6.5  8.0

# %%
data.dropna()
# Out:
#      0    1    2
# 0  1.0  4.5  8.0

# %%
data
# Out:
#      0    1    2
# 0  1.0  4.5  8.0
# 1  1.0  NaN  NaN
# 2  NaN  NaN  NaN
# 3  NaN  6.5  8.0

# %%
data.dropna(how="all")
# Out:
#      0    1    2
# 0  1.0  4.5  8.0
# 1  1.0  NaN  NaN
# 3  NaN  6.5  8.0

# %%
data[4]=NA

# %%
data
# Out:
#      0    1    2   4
# 0  1.0  4.5  8.0 NaN
# 1  1.0  NaN  NaN NaN
# 2  NaN  NaN  NaN NaN
# 3  NaN  6.5  8.0 NaN

# %%
data.dropna(axis=1,how="all")
# Out:
#      0    1    2
# 0  1.0  4.5  8.0
# 1  1.0  NaN  NaN
# 2  NaN  NaN  NaN
# 3  NaN  6.5  8.0

# %%
df=pd.DataFrame(np.random.randn(7,3))

# %%
df
df.iloc[:4,1]=NA
df.iloc[:2,2]=NA
print(df)
# Out:
#           0         1         2
# 0  1.746884       NaN       NaN
# 1  1.003462       NaN       NaN
# 2  1.252608       NaN -0.828173
# 3  1.209124       NaN -0.279607
# 4 -0.351150 -0.924622 -0.180455
# 5  0.768941  0.571624  0.277066
# 6  1.342492  0.941182  1.253533

# %%
df.dropna()
# Out:
#           0         1         2
# 4 -0.351150 -0.924622 -0.180455
# 5  0.768941  0.571624  0.277066
# 6  1.342492  0.941182  1.253533

# %%
df.dropna(thresh=2)
# Out:
#           0         1         2
# 2  1.252608       NaN -0.828173
# 3  1.209124       NaN -0.279607
# 4 -0.351150 -0.924622 -0.180455
# 5  0.768941  0.571624  0.277066
# 6  1.342492  0.941182  1.253533

# %%
df.fillna(0)
# Out:
#           0         1         2
# 0  1.746884  0.000000  0.000000
# 1  1.003462  0.000000  0.000000
# 2  1.252608  0.000000 -0.828173
# 3  1.209124  0.000000 -0.279607
# 4 -0.351150 -0.924622 -0.180455
# 5  0.768941  0.571624  0.277066
# 6  1.342492  0.941182  1.253533

# %%
df.fillna({1:5,2:9})
# Out:
#           0         1         2
# 0  1.746884  5.000000  9.000000
# 1  1.003462  5.000000  9.000000
# 2  1.252608  5.000000 -0.828173
# 3  1.209124  5.000000 -0.279607
# 4 -0.351150 -0.924622 -0.180455
# 5  0.768941  0.571624  0.277066
# 6  1.342492  0.941182  1.253533

# %%
print(df.mean())
# Out:
# 0    0.996052
# 1    0.196061
# 2    0.048473
# dtype: float64

# %%
df.fillna(df.mean())
# Out:
#           0         1         2
# 0  1.746884  0.196061  0.048473
# 1  1.003462  0.196061  0.048473
# 2  1.252608  0.196061 -0.828173
# 3  1.209124  0.196061 -0.279607
# 4 -0.351150 -0.924622 -0.180455
# 5  0.768941  0.571624  0.277066
# 6  1.342492  0.941182  1.253533

# %%
df.fillna(df.mean(),inplace=True)

# %%
df
# Out:
#           0         1         2
# 0  1.746884  0.196061  0.048473
# 1  1.003462  0.196061  0.048473
# 2  1.252608  0.196061 -0.828173
# 3  1.209124  0.196061 -0.279607
# 4 -0.351150 -0.924622 -0.180455
# 5  0.768941  0.571624  0.277066
# 6  1.342492  0.941182  1.253533

# %%
df=pd.DataFrame(np.random.randn(6,3))

# %%
df
# Out:
#           0         1         2
# 0 -1.202839  0.770073 -0.726932
# 1  1.948198  1.362321 -0.468102
# 2 -0.792543  1.280349 -0.181466
# 3 -0.331713  0.983745  0.231061
# 4 -1.367934 -0.174198 -1.109160
# 5  0.275485  0.651985  0.471684

# %%
df.iloc[2:-1,1]=NA
df.iloc[3:-2,2]=NA

# %%
df
# Out:
#           0         1         2
# 0 -1.202839  0.770073 -0.726932
# 1  1.948198  1.362321 -0.468102
# 2 -0.792543       NaN -0.181466
# 3 -0.331713       NaN       NaN
# 4 -1.367934       NaN -1.109160
# 5  0.275485  0.651985  0.471684

# %%
df.fillna(method="ffill")
# Out:
#           0         1         2
# 0 -1.202839  0.770073 -0.726932
# 1  1.948198  1.362321 -0.468102
# 2 -0.792543  1.362321 -0.181466
# 3 -0.331713  1.362321 -0.181466
# 4 -1.367934  1.362321 -1.109160
# 5  0.275485  0.651985  0.471684

# %%
df=pd.DataFrame({"K1":["one","two"]*3+["two"],
                "K2":[1,1,2,2,3,4,4]})

# %%
df
# Out:
#     K1  K2
# 0  one   1
# 1  two   1
# 2  one   2
# 3  two   2
# 4  one   3
# 5  two   4
# 6  two   4

# %%
df.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6     True
# dtype: bool

# %%
df[df.duplicated()]
# Out:
#     K1  K2
# 6  two   4

# %%
df.drop_duplicates()
# Out:
#     K1  K2
# 0  one   1
# 1  two   1
# 2  one   2
# 3  two   2
# 4  one   3
# 5  two   4

# %%
df.drop_duplicates(subset="K1")
# Out:
#     K1  K2
# 0  one   1
# 1  two   1

# %%
df["v1"]=range(7)

# %%
df
# Out:
#     K1  K2  v1
# 0  one   1   0
# 1  two   1   1
# 2  one   2   2
# 3  two   2   3
# 4  one   3   4
# 5  two   4   5
# 6  two   4   6

# %%
df
# Out:
#     K1  K2  v1
# 0  one   1   0
# 1  two   1   1
# 2  one   2   2
# 3  two   2   3
# 4  one   3   4
# 5  two   4   5
# 6  two   4   6

# %%
tran=lambda x:x[:2].upper()

# %%
df.columns.map(tran)
# Out:
# Index(['K1', 'K2', 'V1'], dtype='object')

# %%
df
# Out:
#     K1  K2  v1
# 0  one   1   0
# 1  two   1   1
# 2  one   2   2
# 3  two   2   3
# 4  one   3   4
# 5  two   4   5
# 6  two   4   6

# %%
df.rename(index=str)
# Out:
#     K1  K2  v1
# 0  one   1   0
# 1  two   1   1
# 2  one   2   2
# 3  two   2   3
# 4  one   3   4
# 5  two   4   5
# 6  two   4   6

# %%
df.index=("mahaz","f","fg","h","dg","FG","yt")

# %%
df.rename(index=str.upper,columns=str.title)
# Out:
#         K1  K2  V1
# MAHAZ  one   1   0
# F      two   1   1
# FG     one   2   2
# H      two   2   3
# DG     one   3   4
# FG     two   4   5
# YT     two   4   6

# %%
age=[18,19,20,22,33,44,55,66,75,45,32,19,78,67]
slab=[15,22,35,45,55,70]

# %%
cat=pd.cut(age,slab)

# %%
cat.value_counts()
# Out:
# (15, 22]    5
# (22, 35]    2
# (35, 45]    2
# (45, 55]    1
# (55, 70]    2
# dtype: int64

# %%
name=["young","midle","old","oldest","olddd"]

# %%
cut=pd.cut(age,slab,labels=name)

# %%
cut.value_counts()
# Out:
# young     5
# midle     2
# old       2
# oldest    1
# olddd     2
# dtype: int64
